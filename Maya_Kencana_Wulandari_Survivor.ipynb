# %%
#Soalnomor1
jarak=int(input("Jarak= "))
if (jarak>0) and (jarak<= 10):
  Tarif=10000+(jarak*2500)
  print("Tarif", Tarif)
elif (jarak>10) and (jarak<=25):
  sisa_jarak=jarak-10
  Tarif=10000+(10*2500)+(sisa_jarak*2250)
  print("Tarif", Tarif)
elif (jarak>25) and (jarak<=50):
  sisa_jarak=jarak-25
  Tarif=10000+(10*2500)+(15*2250)+(sisa_jarak*2000)
  print("Tarif", Tarif)
elif (jarak>50) and (jarak<=500):
  sisa_jarak=jarak-50
  Tarif=10000+(10*2500)+(15*2250)+(25*2000)+(sisa_jarak*1750)
else:
  print("Tidak Bisa Melakukan Perjalanan, Batas maksimal 500Km")
# Out:
# Jarak= 45
# Tarif 108750

# %%
#Soalnomor2
a = int(input("Angka Pertama: "))
b = int(input("Angka Kedua: "))
c = int(input("Angka Ketiga: "))

if ((a<0) or (a>5000000)) or ((b<0) or (b>5000000)) or ((c<0) or (c>5000000)):
  print("Bilangan diluar jangakuan")
elif (a>b) and (a>c) and (c>b):
  print (c)
elif (c>b) and (c>a) and (b>a):
  print(b)
elif (a>b) and (c>=a) and (c>b):
  print(a)
elif (a==b) or (a==c):
  print(a)
elif (b==c):
  print(b)
else:
  print("Bilangan di Luar Jangkauan")
# Out:
# Angka Pertama: 5
# Angka Kedua: 5
# Angka Ketiga: 3
# 5

# %%
5
